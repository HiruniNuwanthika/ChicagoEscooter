# %%
import pandas as pd

# %%
#16-30 minutes dataset

df2_=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\2_9hour_part1.csv')
df2=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\2_9hour_part2.csv')
started_list2=[]
#df1[df1["ID_NUMBER"].isin(df2["ID_NUMBER"])]
if (df2['bike_id'].isin(df2_['bike_id']).any()):
    #print('same id')
    df2sameid=df2[df2['bike_id'].isin(df2_['bike_id'])]
    #ff=df2sameid.iloc[:,1:]
    first_col=df2sameid.iloc[:,1:].apply(lambda row: row.first_valid_index(), axis=1)
    for col in range(len(first_col)):
        if(first_col[0].split('_')[1]=='16'):
            #print('it is there!!!!!')
    #print(str(first_col).split('_')[1])
    #print(first)
    #print(df2_same)
            for i in range(17,31):
                try:
                    if 'lat_%s' %(i+1) in df2.columns:
                        started=df2[(df2['lat_%s' %i].isnull()==False) & (df2['lat_%s' %(i+1)].isnull()==True)]
                        started_list2.append(started)
                except KeyError:
                    print("Missing Values: hour "+str(hour)+"_minute "+str(i))
        started_df2= pd.DataFrame()
else:
    for i in range(16,31):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                started=df2[(df2['lat_%s' %i].isnull()==False) & (df2['lat_%s' %(i+1)].isnull()==True)]
                started_list2.append(started)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
    started_df2= pd.DataFrame()
for item in started_list2:
    started_df2 =  started_df2.append(item, ignore_index=True)
started_df2.to_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\Started\TEST\2_9hour_part2sameid.csv',index=False)

# %%
df2_=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\7_0hour_part1.csv') #part before
df2=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\7_0hour_part2.csv') #part
df2__=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\7_0hour_part3.csv') #part after
started_list2=[]
if ((df2['bike_id'].isin(df2_['bike_id']).any())& (df2['bike_id'].isin(df2__['bike_id']).any())):
    print('common in part2 and part3 &&&&&&& common in part3 and part4')
    #df2sameid=df2[df2['bike_id'].isin(df2_['bike_id'])]
    #first_col=df2sameid.iloc[:,1:].apply(lambda row: row.first_valid_index(), axis=1)
    #for col in range(len(first_col)):
       # if(first_col[0].split('_')[1]=='16'):
            #print('it is there!!!!!')
    #print(str(first_col).split('_')[1])
    #print(first)
    #print(df2_same)
    for i in range(17,29):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                started=df2[(df2['lat_%s' %i].isnull()==False) & (df2['lat_%s' %(i+1)].isnull()==True)]
                started_list2.append(started)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
elif (df2['bike_id'].isin(df2_['bike_id']).any()):
    print('common in part2 and part 3')
    for i in range(17,30):
            try:
                if 'lat_%s' %(i+1) in df2.columns:
                    started=df2[(df2['lat_%s' %i].isnull()==False) & (df2['lat_%s' %(i+1)].isnull()==True)]
                    started_list2.append(started)
            except KeyError:
                print("Missing Values: hour "+str(hour)+"_minute "+str(i))
elif (df2['bike_id'].isin(df2__['bike_id']).any()):
    print('common in part3 and part 4')
    for i in range(16,29):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                started=df2[(df2['lat_%s' %i].isnull()==False) & (df2['lat_%s' %(i+1)].isnull()==True)]
                started_list2.append(started)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
else:
    print('no commom')
    for i in range(16,30):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                started=df2[(df2['lat_%s' %i].isnull()==False) & (df2['lat_%s' %(i+1)].isnull()==True)]
                started_list2.append(started)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
started_df2= pd.DataFrame()
for item in started_list2:
    started_df2 =  started_df2.append(item, ignore_index=True)
started_df2.to_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\Started\TEST\7_0hour_part2sameid.csv',index=False)
# Out:
# common in part3 and part 4

# %%
df3_=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\2_21hour_part4.csv')
df3=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\2_21hour_part3.csv')
started_list3=[]
if (df3['bike_id'].isin(df3_['bike_id']).any()):
    print('there are!!!!!!!')
    #df2sameid=df2[df2['bike_id'].isin(df2_['bike_id'])]
    #first_col=df2sameid.iloc[:,1:].apply(lambda row: row.first_valid_index(), axis=1)
    #for col in range(len(first_col)):
       # if(first_col[0].split('_')[1]=='16'):
            #print('it is there!!!!!')
    #print(str(first_col).split('_')[1])
    #print(first)
    #print(df2_same)
    for i in range(31,44):
        try:
            if 'lat_%s' %(i+1) in df3.columns:
                started=df3[(df3['lat_%s' %i].isnull()==False) & (df3['lat_%s' %(i+1)].isnull()==True)]
                started_list3.append(started)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
else:
    for i in range(31,46):
        try:
            if 'lat_%s' %(i+1) in df3.columns:
                started=df3[(df3['lat_%s' %i].isnull()==False) & (df3['lat_%s' %(i+1)].isnull()==True)]
                started_list3.append(started)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
started_df3= pd.DataFrame()
for item in started_list3:
    started_df3 =  started_df3.append(item, ignore_index=True)
started_df3.to_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\Started\TEST\2_21hour_part3sameid.csv',index=False)
# Out:
# there are!!!!!!!

# %%
#16-30 minutes dataset
df2_=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\7_0hour_part1.csv')#part before
df2=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\7_0hour_part2.csv')#part
df2__=pd.read_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\7_0hour_part3.csv')# part after
stopped_list2=[]
if((df2['bike_id'].isin(df2_['bike_id']).any()) & (df2['bike_id'].isin(df2__['bike_id']).any())):
    for i in range(17,29):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                stopped=df2[(df2['lat_%s' %i].isnull()==True) & (df2['lat_%s' %(i+1)].isnull()==False)]
                stopped_list2.append(stopped)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
elif (df2['bike_id'].isin(df2_['bike_id']).any()):
    for i in range(17,30):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                stopped=df2[(df2['lat_%s' %i].isnull()==True) & (df2['lat_%s' %(i+1)].isnull()==False)]
                stopped_list2.append(stopped)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
elif (df2['bike_id'].isin(df2__['bike_id']).any()):
    for i in range(16,29):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                stopped=df2[(df2['lat_%s' %i].isnull()==True) & (df2['lat_%s' %(i+1)].isnull()==False)]
                stopped_list2.append(stopped)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
else:
    for i in range(16,30):
        try:
            if 'lat_%s' %(i+1) in df2.columns:
                stopped=df2[(df2['lat_%s' %i].isnull()==True) & (df2['lat_%s' %(i+1)].isnull()==False)]
                stopped_list2.append(stopped)
        except KeyError:
            print("Missing Values: hour "+str(hour)+"_minute "+str(i))
stopped_df2= pd.DataFrame()
for item in stopped_list2:
    stopped_df2 =  stopped_df2.append(item, ignore_index=True)
stopped_df2.to_csv(r'C:\Melbourne_Escooter\RealDataset\Results\August\Stopped\TEST\7_0hour_part2sameid.csv',index=False)
#31-45 minutes dataset
