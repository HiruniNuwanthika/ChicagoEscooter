# %%
import pandas as pd

# %%
df=pd.read_csv(r'\\rmit.internal\USRHome\sl0\s3923410\Dataset\Melbourne-Test\Pedestrian_Counting_System_-_Sensor_Locations.csv')

# %% [markdown]
# Read sensor locations csv file

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86 entries, 0 to 85
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   sensor_id           86 non-null     int64
#  1   sensor_description  86 non-null     object
#  2   sensor_name         86 non-null     object
#  3   installation_date   86 non-null     object
#  4   status              86 non-null     object
#  5   note                10 non-null     object
#  6   direction_1         78 non-null     object
#  7   direction_2         78 non-null     object
#  8   latitude            86 non-null     float64
#  9   longitude           86 non-null     float64
#  10  location            86 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 7.5+ KB

# %% [markdown]
# Checked information of DF to find number of rows

# %%
df.head()
# Out:
#    sensor_id                sensor_description sensor_name installation_date  \
# 0         57                  Bourke St Bridge    BouBri_T        2018/08/13
# 1         32                       City Square       CSq_T        2013/12/20
# 2         68  Flinders Ln -Degraves St (North)    FLDegN_T        2020/06/03
# 3         40      Lonsdale St-Spring St (West)    Spr201_T        2015/01/19
# 4          1        Bourke Street Mall (North)    Bou292_T        2009/03/24
#
#   status                                  note direction_1 direction_2  \
# 0      A                                   NaN        East        West
# 1      R  Device has been removed (24/01/2017)         NaN         NaN
# 2      A                                   NaN        East        West
# 3      A                                   NaN       South       North
# 4      A                                   NaN        East        West
#
#     latitude   longitude                      location
# ...

# %%
print(df["note"].unique())
# Out:
# [nan 'Device has been removed (24/01/2017)'
#  'Device is upgraded in 26/02/2020' 'Upgraded on 8/09/21'
#  'Sensor relocated to sensor ID 25 on 2/10/2019'
#  'In 4/12/2019 sensor upgraded'
#  'Device moved to location ID 53 (22/09/2015)'
#  'Device has been removed (17/02/2017)' 'Southbank -Building side'
#  'Temporary for the duration of the metro tunnel works. Installed under the scaffolding.'
#  'sensor upgraded from laser to 3D on 19/12/2019']

# %% [markdown]
# Print and see the unique values in notes column

# %%
df[df["note"].str.contains("Device has been removed")==False]
# Out:
#     sensor_id                          sensor_description sensor_name  \
# 8          17                       Collins Place (South)     Col15_T
# 16          6           Flinders Street Station Underpass      FliS_T
# 23         14                            Sandridge Bridge    SanBri_T
# 33         39                                Alfred Place     AlfPl_T
# 49         16                        Australia on Collins    Col270_T
# 53         35                                   Southbank    SouthB_T
# 60         60  Flinders La - Swanston St (West) Temporary    Swa31T_T
# 68         29               St Kilda Rd-Alexandra Gardens        AG_T
#
#    installation_date status  \
# 8         2009/03/30      A
# 16        2009/03/25      A
# 23        2009/03/24      R
# 33        2019/12/04      A
# 49        2009/03/30      R
# 53        2021/04/15      A
# 60        2019/03/08      R
# 68        2013/10/11      A
#
# ...

# %% [markdown]
# Dropped records containig the string "device removed"

# %%
df.to_csv(r'\\rmit.internal\USRHome\sl0\s3923410\Dataset\Melbourne-Test\Pedestrian_Counting_System_-_Sensor_Locations_Dropped_Removed_devices.csv')

# %% [markdown]
# Save cleaned dataset
