# %%
import json
import pandas as pd
with open(r'\\rmit.internal\USRHome\sl0\s3923410\Melbourne\e-scooterSampleDataset\27Jul2022063232GMT.json','r') as f:
    data = json.loads(f.read())

# %% [markdown]
# open file

# %%
df_27_Jul_063232=pd.json_normalize(data, ['data', 'bikes'])

# %% [markdown]
# normalize json file

# %%
df_27_Jul_063232.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bike_id               664 non-null    object
#  1   lat                   664 non-null    float64
#  2   lon                   664 non-null    float64
#  3   is_reserved           664 non-null    bool
#  4   is_disabled           664 non-null    bool
#  5   current_range_meters  664 non-null    int64
#  6   vehicle_type_id       664 non-null    object
#  7   last_reported         664 non-null    int64
#  8   pricing_plan_id       664 non-null    object
#  9   vehicle_type          664 non-null    object
# dtypes: bool(2), float64(2), int64(2), object(4)
# memory usage: 42.9+ KB

# %%
df_27_Jul_063232_escooter=df_27_Jul_063232[df_27_Jul_063232['vehicle_type']=='scooter']

# %% [markdown]
# select only scooter type

# %%
df_27_Jul_063232_escooter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 366 entries, 0 to 663
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bike_id               366 non-null    object
#  1   lat                   366 non-null    float64
#  2   lon                   366 non-null    float64
#  3   is_reserved           366 non-null    bool
#  4   is_disabled           366 non-null    bool
#  5   current_range_meters  366 non-null    int64
#  6   vehicle_type_id       366 non-null    object
#  7   last_reported         366 non-null    int64
#  8   pricing_plan_id       366 non-null    object
#  9   vehicle_type          366 non-null    object
# dtypes: bool(2), float64(2), int64(2), object(4)
# memory usage: 26.4+ KB

# %%
df_27_Jul_063232_escooter=df_27_Jul_063232_escooter[df_27_Jul_063232_escooter['is_disabled']==False]

# %% [markdown]
# select only operating devices

# %%
df_27_Jul_063232_escooter
# Out:
#                                   bike_id        lat         lon  is_reserved  \
# 0    5925a60d-916c-473b-b5b8-2c26ae1b8fda -37.878500  144.997031        False
# 1    444b5be4-1f3d-4312-b4d2-073cf382acab -37.883611  144.995879        False
# 2    d6ec5564-ce24-42c9-8aed-05da19f256b2 -37.883643  144.995767        False
# 5    8cbb6096-fa0b-40d9-9741-d5174b31956d -37.880739  144.991512        False
# 6    738baefd-633d-4baf-8e9a-feaefade920e -37.887645  144.991270        False
# ..                                    ...        ...         ...          ...
# 659  ccab2e5e-183f-45d2-94f1-c33e578029b2 -37.794052  144.922660        False
# 660  3d9a40f3-8dbe-4d56-b3d6-9c56bd2fca99 -37.795731  144.916872        False
# 661  5d09460e-df2a-42c7-8576-7e8b3c956823 -37.795690  144.916801        False
# 662  d8717ed7-f1a9-4f0e-a025-9fbb21e8ccd5 -37.794298  144.916129        False
# 663  44bca40b-826d-4e8f-99d4-35b79f822028 -37.783774  144.907391        False
#
# ...

# %%
df_27_Jul_063232_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','current_range_meters','last_reported','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %% [markdown]
# drop columns except id, long,lat

# %%
df_27_Jul_063232_escooter
# Out:
#                                   bike_id        lat         lon
# 0    5925a60d-916c-473b-b5b8-2c26ae1b8fda -37.878500  144.997031
# 1    444b5be4-1f3d-4312-b4d2-073cf382acab -37.883611  144.995879
# 2    d6ec5564-ce24-42c9-8aed-05da19f256b2 -37.883643  144.995767
# 5    8cbb6096-fa0b-40d9-9741-d5174b31956d -37.880739  144.991512
# 6    738baefd-633d-4baf-8e9a-feaefade920e -37.887645  144.991270
# ..                                    ...        ...         ...
# 659  ccab2e5e-183f-45d2-94f1-c33e578029b2 -37.794052  144.922660
# 660  3d9a40f3-8dbe-4d56-b3d6-9c56bd2fca99 -37.795731  144.916872
# 661  5d09460e-df2a-42c7-8576-7e8b3c956823 -37.795690  144.916801
# 662  d8717ed7-f1a9-4f0e-a025-9fbb21e8ccd5 -37.794298  144.916129
# 663  44bca40b-826d-4e8f-99d4-35b79f822028 -37.783774  144.907391
#
# [366 rows x 3 columns]

# %%
with open(r'\\rmit.internal\USRHome\sl0\s3923410\Melbourne\e-scooterSampleDataset\27Jul2022063824GMT.json','r') as f:
    data = json.loads(f.read())

# %% [markdown]
# read json file

# %%
df_27_Jul_063832=pd.json_normalize(data, ['data', 'bikes'])

# %% [markdown]
# normalize data

# %%
df_27_Jul_063832.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bike_id               658 non-null    object
#  1   lat                   658 non-null    float64
#  2   lon                   658 non-null    float64
#  3   is_reserved           658 non-null    bool
#  4   is_disabled           658 non-null    bool
#  5   current_range_meters  658 non-null    int64
#  6   vehicle_type_id       658 non-null    object
#  7   last_reported         658 non-null    int64
#  8   pricing_plan_id       658 non-null    object
#  9   vehicle_type          658 non-null    object
# dtypes: bool(2), float64(2), int64(2), object(4)
# memory usage: 42.5+ KB

# %%
df_27_Jul_063832_escooter=df_27_Jul_063832[df_27_Jul_063832['vehicle_type']=='scooter']

# %% [markdown]
# select scooter type only

# %%
df_27_Jul_063832_escooter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 361 entries, 2 to 657
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bike_id               361 non-null    object
#  1   lat                   361 non-null    float64
#  2   lon                   361 non-null    float64
#  3   is_reserved           361 non-null    bool
#  4   is_disabled           361 non-null    bool
#  5   current_range_meters  361 non-null    int64
#  6   vehicle_type_id       361 non-null    object
#  7   last_reported         361 non-null    int64
#  8   pricing_plan_id       361 non-null    object
#  9   vehicle_type          361 non-null    object
# dtypes: bool(2), float64(2), int64(2), object(4)
# memory usage: 26.1+ KB

# %%
df_27_Jul_063832_escooter=df_27_Jul_063832_escooter[df_27_Jul_063832_escooter['is_disabled']==False]

# %% [markdown]
# select operating devices only

# %%
df_27_Jul_063832_escooter
# Out:
#                                   bike_id        lat         lon  is_reserved  \
# 2    a79cc89b-7a01-4dd9-bb32-dd8bf5d51e1f -37.872682  144.998057        False
# 3    444b5be4-1f3d-4312-b4d2-073cf382acab -37.883611  144.995879        False
# 4    d6ec5564-ce24-42c9-8aed-05da19f256b2 -37.883611  144.995734        False
# 7    8cbb6096-fa0b-40d9-9741-d5174b31956d -37.880757  144.991373        False
# 8    738baefd-633d-4baf-8e9a-feaefade920e -37.887645  144.991270        False
# ..                                    ...        ...         ...          ...
# 651  8152e6ac-083d-4fba-86e7-c496773567a2 -37.839206  144.918281        False
# 653  3d9a40f3-8dbe-4d56-b3d6-9c56bd2fca99 -37.795731  144.916872        False
# 654  5d09460e-df2a-42c7-8576-7e8b3c956823 -37.795732  144.916845        False
# 656  d8717ed7-f1a9-4f0e-a025-9fbb21e8ccd5 -37.794298  144.916129        False
# 657  44bca40b-826d-4e8f-99d4-35b79f822028 -37.783774  144.907391        False
#
# ...

# %%
df_27_Jul_063832_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','current_range_meters','last_reported','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %% [markdown]
# remove columns except id, lat,long

# %%
df_27_Jul_063832_escooter
# Out:
#                                   bike_id        lat         lon
# 2    a79cc89b-7a01-4dd9-bb32-dd8bf5d51e1f -37.872682  144.998057
# 3    444b5be4-1f3d-4312-b4d2-073cf382acab -37.883611  144.995879
# 4    d6ec5564-ce24-42c9-8aed-05da19f256b2 -37.883611  144.995734
# 7    8cbb6096-fa0b-40d9-9741-d5174b31956d -37.880757  144.991373
# 8    738baefd-633d-4baf-8e9a-feaefade920e -37.887645  144.991270
# ..                                    ...        ...         ...
# 651  8152e6ac-083d-4fba-86e7-c496773567a2 -37.839206  144.918281
# 653  3d9a40f3-8dbe-4d56-b3d6-9c56bd2fca99 -37.795731  144.916872
# 654  5d09460e-df2a-42c7-8576-7e8b3c956823 -37.795732  144.916845
# 656  d8717ed7-f1a9-4f0e-a025-9fbb21e8ccd5 -37.794298  144.916129
# 657  44bca40b-826d-4e8f-99d4-35b79f822028 -37.783774  144.907391
#
# [361 rows x 3 columns]

# %%
df_all = pd.concat([df_27_Jul_063232_escooter.set_index('bike_id'), df_27_Jul_063832_escooter.set_index('bike_id')], axis='columns', keys=['First', 'Second'])

# %% [markdown]
# Concatenate 2 data frames making id index in both frames

# %%
df_all.to_csv(r'\\rmit.internal\USRHome\sl0\s3923410\Melbourne\e-scooterSampleDataset\compare.csv')

# %% [markdown]
# save conceted frame into csv

# %%
df_final = df_all.swaplevel(axis='columns')[df_27_Jul_063232_escooter.columns[1:]]
df_final
# Out:
#                                             lat                    lon  \
#                                           First     Second       First
# bike_id
# 5925a60d-916c-473b-b5b8-2c26ae1b8fda -37.878500 -37.878500  144.997031
# 444b5be4-1f3d-4312-b4d2-073cf382acab -37.883611 -37.883611  144.995879
# d6ec5564-ce24-42c9-8aed-05da19f256b2 -37.883643 -37.883611  144.995767
# 8cbb6096-fa0b-40d9-9741-d5174b31956d -37.880739 -37.880757  144.991512
# 738baefd-633d-4baf-8e9a-feaefade920e -37.887645 -37.887645  144.991270
# ...                                         ...        ...         ...
# 766afc26-72de-426a-9751-a8a25c46cbb7        NaN -37.795241         NaN
# 48f5433e-b554-4c7a-b7f5-fc4bf39ae352        NaN -37.790024         NaN
# 95df6300-eed1-44c1-9083-fe5de0df50af        NaN -37.819814         NaN
# aa0c25c4-49c8-4d52-a663-68ace9ef1bd3        NaN -37.814984         NaN
# 6e4f3668-b074-44d3-ade5-4c7efaaea2c0        NaN -37.820842         NaN
#
#
# ...

# %% [markdown]
# make same name columns together, so easy to compare

# %%
import numpy as np
def highlight_diff(data, color='yellow'):
    attr = 'background-color: {}'.format(color)
    other = data.xs('First', axis='columns', level=-1)
    return pd.DataFrame(np.where(data.ne(other, level=0), attr, ''),
                        index=data.index, columns=data.columns)

df_final.style.apply(highlight_diff, axis=None)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# Highlight changed values
