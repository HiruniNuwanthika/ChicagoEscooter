# %%
import pandas as pd
import json
import pandas as pd
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t16_56.json','r') as f:
    data = json.loads(f.read())

# %% [markdown]
# Check whether dataset includes only available devices data.
# 1.The vehicle driven 16.57 to 17.01
# 2.Data available in 16.56 not in 16.57,16.58,16.59,17.0,17.1,17.2
# 3.Again record can be seen from 17.3 onwards
# 4.We can assume data set includes available devices data

# %% [markdown]
# Check ID change
# 1.ID get changed hourly
# 2.eg: 15:01 to 16:00  IDs are same
# 16:00 and 16:01 different
# hourly new ID starts at first minute of the hour

# %%
df_16_56=pd.json_normalize(data, ['data', 'bikes'])

# %%
df_16_56_escooter=df_16_56[df_16_56['vehicle_type']=='scooter']

# %%
df_16_56_escooter
# Out:
#                                   bike_id        lat         lon  is_reserved  \
# 0    062af51f-5740-4059-bb2e-20ee7b9a8118 -37.878515  144.997101        False
# 1    7dc2262f-b267-4475-8472-01b79f433936 -37.883660  144.996219        False
# 5    e1b4582d-628c-4ce9-9d50-6de599085062 -37.880816  144.991357        False
# 6    ddc0cee8-1863-484a-9db9-1c96b5656635 -37.890345  144.990871        False
# 8    9158b0e9-e763-427c-8f7e-3a8debd26638 -37.878620  144.990128        False
# ..                                    ...        ...         ...          ...
# 664  87f05d90-04fc-4287-aa2b-289e4b70582d -37.831422  144.918822        False
# 666  6433bb1c-a0aa-43c3-a9f7-67935c5ff9e1 -37.781700  144.909860        False
# 667  e7f1ee7d-ac6d-4f46-a12a-39f6e801ff8b -37.806727  144.908978        False
# 668  5e0ec29b-2922-41fd-8565-568623732d3d -37.787943  144.905924        False
# 669  f7b31e10-d4a2-4233-96ab-011e891b57da -37.833929  144.900919        False
#
# ...

# %%
df_16_56_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_16_56_escooter
# Out:
#                                   bike_id        lat         lon  \
# 0    062af51f-5740-4059-bb2e-20ee7b9a8118 -37.878515  144.997101
# 1    7dc2262f-b267-4475-8472-01b79f433936 -37.883660  144.996219
# 5    e1b4582d-628c-4ce9-9d50-6de599085062 -37.880816  144.991357
# 6    ddc0cee8-1863-484a-9db9-1c96b5656635 -37.890345  144.990871
# 8    9158b0e9-e763-427c-8f7e-3a8debd26638 -37.878620  144.990128
# ..                                    ...        ...         ...
# 664  87f05d90-04fc-4287-aa2b-289e4b70582d -37.831422  144.918822
# 666  6433bb1c-a0aa-43c3-a9f7-67935c5ff9e1 -37.781700  144.909860
# 667  e7f1ee7d-ac6d-4f46-a12a-39f6e801ff8b -37.806727  144.908978
# 668  5e0ec29b-2922-41fd-8565-568623732d3d -37.787943  144.905924
# 669  f7b31e10-d4a2-4233-96ab-011e891b57da -37.833929  144.900919
#
#      current_range_meters  last_reported
# 0                    5816     1659250528
# 1                   12955     1659250528
# 5                    5999     1659250528
# ...

# %%
import pandas as pd
import json
import pandas as pd
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t16_57.json','r') as f:
    data = json.loads(f.read())

# %%
df_16_57=pd.json_normalize(data, ['data', 'bikes'])

# %%
df_16_57_escooter=df_16_57[df_16_57['vehicle_type']=='scooter']

# %%
df_16_57_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t16_58.json','r') as f:
    data = json.loads(f.read())

# %%
df_16_58=pd.json_normalize(data, ['data', 'bikes'])
df_16_58_escooter=df_16_58[df_16_58['vehicle_type']=='scooter']
df_16_58_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t16_59.json','r') as f:
    data = json.loads(f.read())

# %%
df_16_59=pd.json_normalize(data, ['data', 'bikes'])
df_16_59_escooter=df_16_59[df_16_59['vehicle_type']=='scooter']
df_16_59_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t17_0.json','r') as f:
    data = json.loads(f.read())

# %%
df_17_0=pd.json_normalize(data, ['data', 'bikes'])
df_17_0_escooter=df_17_0[df_17_0['vehicle_type']=='scooter']
df_17_0_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t17_1.json','r') as f:
    data = json.loads(f.read())

# %%
df_17_1=pd.json_normalize(data, ['data', 'bikes'])
df_17_1_escooter=df_17_1[df_17_1['vehicle_type']=='scooter']
df_17_1_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
df_57_58 = pd.concat([df_16_57_escooter.set_index('bike_id'), df_16_58_escooter.set_index('bike_id')], axis='columns', keys=['First', 'Second'])

# %%
df_57_58
# Out:
#                                           First              \
#                                             lat         lon
# bike_id
# 1bbadf85-5882-4e7b-a306-53fbe90e9f38 -37.860408  145.010429
# 4058aa52-65cd-4a0e-ba54-ee297bedbb71 -37.864052  145.009860
# 9b99ce7d-c49d-41b0-8831-9fb397e1bfde -37.863585  145.007531
# fdfe2dda-17d6-481d-a719-65e70524b21a -37.859248  145.001230
# 19184ebe-a860-4441-9e17-d688588fd55d -37.859233  145.001195
# ...                                         ...         ...
# e7f1ee7d-ac6d-4f46-a12a-39f6e801ff8b -37.806727  144.908978
# 5e0ec29b-2922-41fd-8565-568623732d3d -37.787943  144.905924
# f7b31e10-d4a2-4233-96ab-011e891b57da -37.833929  144.900919
# df46b434-f548-488e-819b-d1d918210168        NaN         NaN
# 8e3b3af3-e895-490d-ae63-e2f56f285343        NaN         NaN
#
#                                                                          \
#                                      current_range_meters last_reported
# bike_id
# ...

# %%
df_59_0 = pd.concat([df_16_59_escooter.set_index('bike_id'), df_17_0_escooter.set_index('bike_id')], axis='columns', keys=['59', '0'])

# %%
df_57_58
# Out:
#                                              57              \
#                                             lat         lon
# bike_id
# 1bbadf85-5882-4e7b-a306-53fbe90e9f38 -37.860408  145.010429
# 4058aa52-65cd-4a0e-ba54-ee297bedbb71 -37.864052  145.009860
# 9b99ce7d-c49d-41b0-8831-9fb397e1bfde -37.863585  145.007531
# fdfe2dda-17d6-481d-a719-65e70524b21a -37.859248  145.001230
# 19184ebe-a860-4441-9e17-d688588fd55d -37.859233  145.001195
# ...                                         ...         ...
# e7f1ee7d-ac6d-4f46-a12a-39f6e801ff8b -37.806727  144.908978
# 5e0ec29b-2922-41fd-8565-568623732d3d -37.787943  144.905924
# f7b31e10-d4a2-4233-96ab-011e891b57da -37.833929  144.900919
# df46b434-f548-488e-819b-d1d918210168        NaN         NaN
# 8e3b3af3-e895-490d-ae63-e2f56f285343        NaN         NaN
#
#                                                                          \
#                                      current_range_meters last_reported
# bike_id
# ...

# %%
df_59_0 .to_csv(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\Test\NEW59_0.csv')

# %%
df_1_2 = pd.concat([df_17_1_escooter.set_index('bike_id'), df_17_2_escooter.set_index('bike_id')], axis='columns', keys=['1', '2'])

# %%
df_1_2.to_csv(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\Test\NEW1_2.csv')

# %%
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t17_2.json','r') as f:
    data = json.loads(f.read())

# %%
df_17_2=pd.json_normalize(data, ['data', 'bikes'])
df_17_2_escooter=df_17_2[df_17_2['vehicle_type']=='scooter']
df_17_2_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
df_1_2 = pd.concat([df_17_1_escooter.set_index('bike_id'), df_17_2_escooter.set_index('bike_id')], axis='columns', keys=['1', '2'])

# %%
df_1_2.to_csv(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\Test\1_2.csv')

# %%
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t17_3.json','r') as f:
    data = json.loads(f.read())

# %%
df_17_3=pd.json_normalize(data, ['data', 'bikes'])
df_17_3_escooter=df_17_3[df_17_3['vehicle_type']=='scooter']
df_17_3_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
df_2_3 = pd.concat([df_17_2_escooter.set_index('bike_id'), df_17_3_escooter.set_index('bike_id')], axis='columns', keys=['2', '3'])

# %%
df_2_3.to_csv(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\Test\NEW2_3.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22608\2322330269.py in <module>
# ----> 1 df_2_3.to_csv(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\Test\NEW2_3.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ...

# %%
import pandas as pd
import json
with open(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\7_31t17_4.json','r') as f:
    data = json.loads(f.read())

# %%
df_17_4=pd.json_normalize(data, ['data', 'bikes'])
df_17_4_escooter=df_17_4[df_17_4['vehicle_type']=='scooter']
df_17_4_escooter.drop(['is_reserved', 'is_disabled','vehicle_type_id','pricing_plan_id','vehicle_type'], axis=1, inplace=True)

# %%
df_17_4.to_csv(r'C:\Melbourne_Escooter\Lime\Scheduled_downloads\Test\TEST17_4.csv', index=False)
